# %%
import pandas as pd
import seaborn as sns
import yaml
import matplotlib.pyplot as plt
import numpy as np

# %%
with open("../config.yaml", "r") as file:
    config = yaml.safe_load(file)

# %%
demo_df = pd.read_csv(config["input_data"]["file1"])
demo_df
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70604    7993686             4.0              56.0      38.5     U        3.0
# 70605    8981690            12.0             148.0      31.0     M        2.0
# 70606     333913            16.0             198.0      61.5     F        2.0
# 70607    1573142            21.0             255.0      68.0     M        3.0
# 70608    5602139            21.0             254.0      59.5     F        3.0
#
#               bal  calls_6_mnth  logons_6_mnth
# 0        45105.30           6.0            9.0
# 1       110860.30           6.0            9.0
# 2        52467.79           6.0            9.0
# 3        67454.65           3.0            6.0
# 4       103671.75           0.0            3.0
# ...           ...           ...            ...
# 70604  1411062.68           5.0            5.0
# 70605   101867.07           6.0            6.0
# 70606    40745.00           3.0            3.0
# 70607   475114.69           4.0            4.0
# 70608   157498.73           7.0            7.0
#
# [70609 rows x 9 columns]

# %%
demo_df.shape
# Out:
# (70609, 9)

# %%
demo_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 70609 entries, 0 to 70608
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   client_id         70609 non-null  int64
#  1   clnt_tenure_yr    70595 non-null  float64
#  2   clnt_tenure_mnth  70595 non-null  float64
#  3   clnt_age          70594 non-null  float64
#  4   gendr             70595 non-null  str
#  5   num_accts         70595 non-null  float64
#  6   bal               70595 non-null  float64
#  7   calls_6_mnth      70595 non-null  float64
#  8   logons_6_mnth     70595 non-null  float64
# dtypes: float64(7), int64(1), str(1)
# memory usage: 4.8 MB

# %%
print(demo_df.dtypes)
# Out:
# client_id             int64
# clnt_tenure_yr      float64
# clnt_tenure_mnth    float64
# clnt_age            float64
# gendr                   str
# num_accts           float64
# bal                 float64
# calls_6_mnth        float64
# logons_6_mnth       float64
# dtype: object

# %%
sorted_balance = demo_df.sort_values(by='bal')
sorted_balance
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 57006    9020160             9.0             108.0      63.0     F        1.0
# 55126     989035            15.0             184.0      41.0     M        2.0
# 61826    3280109            15.0             185.0      59.0     F        2.0
# 66292    9862353            17.0             205.0      59.0     M        2.0
# 53141    2210130             8.0             105.0      18.0     M        2.0
# ...          ...             ...               ...       ...   ...        ...
# 46076    8611797             NaN               NaN       NaN   NaN        NaN
# 47189    5144725             NaN               NaN       NaN   NaN        NaN
# 49846    1037867             NaN               NaN       NaN   NaN        NaN
# 63701    1618749             NaN               NaN       NaN   NaN        NaN
# 66219    6021001             NaN               NaN       NaN   NaN        NaN
#
#             bal  calls_6_mnth  logons_6_mnth
# 57006  13789.42           2.0            2.0
# 55126  13791.34           1.0            1.0
# 61826  13791.80           7.0            7.0
# 66292  13792.98           7.0            7.0
# 53141  13793.69           3.0            3.0
# ...         ...           ...            ...
# 46076       NaN           NaN            NaN
# 47189       NaN           NaN            NaN
# 49846       NaN           NaN            NaN
# 63701       NaN           NaN            NaN
# 66219       NaN           NaN            NaN
#
# [70609 rows x 9 columns]

# %% [markdown]
# There are a some rows without any data except a client ID. They are unusable so let's drop them

# %%
demo_df_cleaned = demo_df.dropna(how='all', subset=demo_df.columns.difference(['client_id']))
demo_df_cleaned = demo_df_cleaned.reset_index(drop=True)
demo_df_cleaned
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70590    7993686             4.0              56.0      38.5     U        3.0
# 70591    8981690            12.0             148.0      31.0     M        2.0
# 70592     333913            16.0             198.0      61.5     F        2.0
# 70593    1573142            21.0             255.0      68.0     M        3.0
# 70594    5602139            21.0             254.0      59.5     F        3.0
#
#               bal  calls_6_mnth  logons_6_mnth
# 0        45105.30           6.0            9.0
# 1       110860.30           6.0            9.0
# 2        52467.79           6.0            9.0
# 3        67454.65           3.0            6.0
# 4       103671.75           0.0            3.0
# ...           ...           ...            ...
# 70590  1411062.68           5.0            5.0
# 70591   101867.07           6.0            6.0
# 70592    40745.00           3.0            3.0
# 70593   475114.69           4.0            4.0
# 70594   157498.73           7.0            7.0
#
# [70595 rows x 9 columns]

# %%
#save cleaned data file
#demo_df_cleaned.to_csv('demo_df_cleaned.csv', index=False)

# %%
demo_df_cleaned.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 70595 entries, 0 to 70594
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   client_id         70595 non-null  int64
#  1   clnt_tenure_yr    70595 non-null  float64
#  2   clnt_tenure_mnth  70595 non-null  float64
#  3   clnt_age          70594 non-null  float64
#  4   gendr             70595 non-null  str
#  5   num_accts         70595 non-null  float64
#  6   bal               70595 non-null  float64
#  7   calls_6_mnth      70595 non-null  float64
#  8   logons_6_mnth     70595 non-null  float64
# dtypes: float64(7), int64(1), str(1)
# memory usage: 4.8 MB

# %% [markdown]
# Only 1 NaN value left in age column. We will ignore this Nan value since it will not distort our research

# %%
#check how many time clients logged on in the last 6 months
sorted_unique_values = sorted(demo_df_cleaned['logons_6_mnth'].unique())

print(sorted_unique_values)
# Out:
# [np.float64(1.0), np.float64(2.0), np.float64(3.0), np.float64(4.0), np.float64(5.0), np.float64(6.0), np.float64(7.0), np.float64(8.0), np.float64(9.0)]

# %%
demo_df_cleaned['logons_6_mnth'].unique()
# Out:
# array([9., 6., 3., 5., 4., 8., 7., 1., 2.])

# %%
joined_df = pd.read_csv(config["output_data"]["file5"])

# %%
# Create a Boolean series to filter users with 9 logons
top_users_filter = joined_df['logons_6_mnth'] == 9

# Filter the DataFrame using the Boolean series
top_users = joined_df[top_users_filter]

# Display the first few rows of the filtered result
display(top_users)
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 9        8198645            15.0             189.0      54.5     F        2.0
# 11       2537139             8.0              99.0      51.5     U        2.0
# ...          ...             ...               ...       ...   ...        ...
# 50473    3823121            14.0             178.0      68.5     F        2.0
# 50477    6751438             8.0              98.0      49.5     U        2.0
# 50481    9932367            23.0             280.0      57.0     F        2.0
# 50483    1780858            21.0             262.0      68.5     M        3.0
# 50484    6967120            21.0             260.0      68.5     M        3.0
#
#               bal  calls_6_mnth  logons_6_mnth variation
# 0        45105.30           6.0            9.0      test
# 1       110860.30           6.0            9.0   control
# 2        52467.79           6.0            9.0      test
# 9       382303.83           6.0            9.0      test
# 11      135940.68           6.0            9.0   control
# ...           ...           ...            ...       ...
# 50473    32666.22           6.0            9.0      test
# 50477   416988.75           6.0            9.0      test
# 50481    94466.55           6.0            9.0   control
# 50483   372100.59           6.0            9.0      test
# 50484  4279873.38           6.0            9.0   control
#
# [12350 rows x 10 columns]

# %% [markdown]
# There are 12.350 clients how logged on 9 times in the last 6 months

# %%
#sort clients by ages
top_users_age = top_users.sort_values(by= 'clnt_age')
display(top_users_age)
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 2716     6516140             5.0              66.0      17.5     U        2.0
# 23120    8927242             3.0              39.0      17.5     U        3.0
# 22034    8365990             3.0              40.0      17.5     U        2.0
# 2283     5269888            20.0             243.0      17.5     F        2.0
# 3195     5747508             5.0              66.0      17.5     U        2.0
# ...          ...             ...               ...       ...   ...        ...
# 45342    1359640            12.0             148.0      92.0     M        2.0
# 33047    6533602            29.0             348.0      93.0     F        2.0
# 42551    3112487             7.0              91.0      93.0     U        2.0
# 35861    5890936            28.0             347.0      93.5     M        3.0
# 31161    2859040            24.0             288.0      96.0     M        2.0
#
#               bal  calls_6_mnth  logons_6_mnth variation
# 2716     74939.63           6.0            9.0   control
# 23120    56048.17           6.0            9.0      test
# 22034    66353.04           6.0            9.0   control
# 2283     39631.34           6.0            9.0      test
# 3195     42447.47           6.0            9.0      test
# ...           ...           ...            ...       ...
# 45342   596701.54           6.0            9.0   control
# 33047   362103.22           6.0            9.0   control
# 42551    30461.89           6.0            9.0   control
# 35861  1364856.21           6.0            9.0   control
# 31161    36297.66           6.0            9.0      test
#
# [12350 rows x 10 columns]

# %%
# Group by 'clnt_age' and count the number of occurrences
age_distribution = top_users_age.groupby('clnt_age').size().reset_index(name='client_count')

# Sort the resulting DataFrame by 'clnt_age' for readability
age_distribution_sorted = age_distribution.sort_values(by='clnt_age')

# Display the DataFrame showing the number of clients of each age
display(age_distribution_sorted)
# Out:
#      clnt_age  client_count
# 0        17.5             5
# 1        18.0            11
# 2        18.5            20
# 3        19.0            11
# 4        19.5            24
# ..        ...           ...
# 145      91.5             1
# 146      92.0             1
# 147      93.0             2
# 148      93.5             1
# 149      96.0             1
#
# [150 rows x 2 columns]

# %%
# Calculate the mean age
mean_age = top_users_age['clnt_age'].mean()
print(f"Mean age: {mean_age}")

# Calculate the median age
median_age = top_users_age['clnt_age'].median()
print(f"Median age: {median_age}")

# Calculate the mode(s) of the ages using dropna() to ensure accuracy
mode_age = top_users_age['clnt_age'].dropna().mode()
print(f"Mode age(s): {mode_age.tolist()}")

percentiles = top_users_age['clnt_age'].quantile([0.25, 0.50, 0.75])
print(percentiles)
# Out:
# Mean age: 47.491133603238865
# Median age: 48.0
# Mode age(s): [27.5]
# 0.25    32.5
# 0.50    48.0
# 0.75    61.0
# Name: clnt_age, dtype: float64

# %%
sns.boxplot(x = age_distribution['clnt_age'], color="#96151D");

# %%
sns.boxplot(x = joined_df['clnt_age'], color="#96151D");

# %%
joined_df.columns
# Out:
# Index(['client_id', 'clnt_tenure_yr', 'clnt_tenure_mnth', 'clnt_age', 'gendr',
#        'num_accts', 'bal', 'calls_6_mnth', 'logons_6_mnth', 'variation'],
#       dtype='str')

# %%
#Categorize ages into bins
joined_df['age_group'] = pd.cut(joined_df['clnt_age'], bins=range(20, 100, 10))

# Create the boxplot with age groups
plt.figure(figsize=(12, 6))
sns.boxplot(data=joined_df, x='age_group', y='logons_6_mnth', color="#96151D")

# Add labels and title
plt.title('Boxplot of Logons by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Logons in the Last 6 Months')

# Display the plot
plt.show()

# %%
# Filter clients with zero logons and zero calls in the last 6 months
clients_with_no_activity = joined_df[(joined_df['logons_6_mnth'] == 0) & (joined_df['calls_6_mnth'] == 0)]

# Extract ages and tenure years
selected_info = clients_with_no_activity[['clnt_age', 'clnt_tenure_yr']]

# Display the selected information
print("Ages and Tenure Years of Clients with Zero Activity:")
print(selected_info)
# Out:
# Ages and Tenure Years of Clients with Zero Activity:
# Empty DataFrame
# Columns: [clnt_age, clnt_tenure_yr]
# Index: []

# %% [markdown]
# There are no clients that did not interact with the back via call or logon.

# %%
#Categorize ages into bins
joined_df['age_group'] = pd.cut(joined_df['clnt_age'], bins=range(20, 100, 10))

# Create the boxplot with age groups
plt.figure(figsize=(12, 6))
sns.boxplot(data=joined_df, x='age_group', y='calls_6_mnth', color="#333333")

# Add labels and title
plt.title('Boxplot of calls by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Calls in the Last 6 Months')

# Display the plot
plt.show()

# %% [markdown]
# Clients between  are using the online log in between 48 and 61 most.
# Everyone is also still using the phone with most clients calling 3 or 4 times in 6 months.

# %%
sns.boxplot(x = joined_df['clnt_tenure_yr'], color="#333333");

# %%
# Checking max for consistent binning, rounding up ensures integer bin boundaries
max_tenure_numeric = np.ceil(joined_df['clnt_tenure_yr'].max())

# Adjust bin edges for integer demarcation using float
bin_edges = np.arange(0, max_tenure_numeric + 5, 5)  # Intervals of 5, adjusted automatically

# Categorize ages into bins
joined_df['tenure_group'] = pd.cut(joined_df['clnt_tenure_yr'], bins=bin_edges)

# Create the boxplot with tenure groups
plt.figure(figsize=(14, 6))
sns.boxplot(data=joined_df, x='tenure_group', y='logons_6_mnth', color="#96151D")

# Add labels and title
plt.title('Boxplot of Logons per Tenure Group')
plt.xlabel('Tenure Group')
plt.ylabel('Logons in the Last 6 Months')

# Display the plot
plt.show()

# %%
# Checking max for consistent binning, rounding up ensures integer bin boundaries
max_tenure_numeric = np.ceil(joined_df['clnt_tenure_yr'].max())

# Adjust bin edges for integer demarcation using float
bin_edges = np.arange(0, max_tenure_numeric + 5, 5)  # Intervals of 5, adjusted automatically

# Categorize ages into bins
joined_df['tenure_group'] = pd.cut(joined_df['clnt_tenure_yr'], bins=bin_edges)

# Create the boxplot with tenure groups
plt.figure(figsize=(14, 6))
sns.boxplot(data=joined_df, x='tenure_group', y='calls_6_mnth', color="#333333")

# Add labels and title
plt.title('Boxplot of Calls per Tenure Group')
plt.xlabel('Tenure Group')
plt.ylabel('Calls in the Last 6 Months')

# Display the plot
plt.show()

# %%
expi_df = pd.read_csv(config["output_data"]["file2"])
expi_df
# Out:
#        client_id Variation
# 0        9988021      test
# 1        8320017      test
# 2        4033851   control
# 3        1982004      test
# 4        9294070   control
# ...          ...       ...
# 50495     393005   control
# 50496    2908510   control
# 50497    7230446      test
# 50498    5230357      test
# 50499    6334360      test
#
# [50500 rows x 2 columns]

# %% [markdown]
# To find out which clients belong to the test group we will join the data with the test and control groups to the demo data

# %%
joined_demo_expi_df = pd.merge(demo_df_cleaned, expi_df, on= 'client_id')
display(joined_demo_expi_df)
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 50483    1780858            21.0             262.0      68.5     M        3.0
# 50484    6967120            21.0             260.0      68.5     M        3.0
# 50485    5826160            20.0             249.0      56.5     F        2.0
# 50486    8739285            19.0             229.0      69.5     F        2.0
# 50487    7468138            18.0             222.0      61.0     F        3.0
#
#               bal  calls_6_mnth  logons_6_mnth Variation
# 0        45105.30           6.0            9.0      test
# 1       110860.30           6.0            9.0   control
# 2        52467.79           6.0            9.0      test
# 3        67454.65           3.0            6.0      test
# 4       103671.75           0.0            3.0   control
# ...           ...           ...            ...       ...
# 50483   372100.59           6.0            9.0      test
# 50484  4279873.38           6.0            9.0   control
# 50485    44837.16           2.0            5.0      test
# 50486    44994.24           1.0            4.0      test
# 50487   209278.15           0.0            3.0      test
#
# [50488 rows x 10 columns]

# %%
joined_demo_expi_df.columns = joined_demo_expi_df.columns.str.lower()
display(joined_demo_expi_df)
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 50483    1780858            21.0             262.0      68.5     M        3.0
# 50484    6967120            21.0             260.0      68.5     M        3.0
# 50485    5826160            20.0             249.0      56.5     F        2.0
# 50486    8739285            19.0             229.0      69.5     F        2.0
# 50487    7468138            18.0             222.0      61.0     F        3.0
#
#               bal  calls_6_mnth  logons_6_mnth variation
# 0        45105.30           6.0            9.0      test
# 1       110860.30           6.0            9.0   control
# 2        52467.79           6.0            9.0      test
# 3        67454.65           3.0            6.0      test
# 4       103671.75           0.0            3.0   control
# ...           ...           ...            ...       ...
# 50483   372100.59           6.0            9.0      test
# 50484  4279873.38           6.0            9.0   control
# 50485    44837.16           2.0            5.0      test
# 50486    44994.24           1.0            4.0      test
# 50487   209278.15           0.0            3.0      test
#
# [50488 rows x 10 columns]

# %%
#save joined data file
#joined_demo_expi_df.to_csv('joined_demo_expi_df.csv', index=False)

# %%
#split the group to test group and control group
# Split the DataFrame into 'test' and 'control' variations
test_df = joined_df[joined_df['variation'] == 'test']
control_df = joined_df[joined_df['variation'] == 'control']

# Display the test and control DataFrames
print("Test DataFrame:")
display(test_df)
print("\nControl DataFrame:")
display(control_df)
# Out:
# Test DataFrame:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 7         388801            30.0             361.0      57.5     M        5.0
# 9        8198645            15.0             189.0      54.5     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 50480     501496            23.0             281.0      35.0     F        2.0
# 50483    1780858            21.0             262.0      68.5     M        3.0
# 50485    5826160            20.0             249.0      56.5     F        2.0
# 50486    8739285            19.0             229.0      69.5     F        2.0
# 50487    7468138            18.0             222.0      61.0     F        3.0
#
#              bal  calls_6_mnth  logons_6_mnth variation age_group  \
# 0       45105.30           6.0            9.0      test  (60, 70]
# 2       52467.79           6.0            9.0      test  (30, 40]
# 3       67454.65           3.0            6.0      test  (40, 50]
# 7      522498.72           1.0            4.0      test  (50, 60]
# 9      382303.83           6.0            9.0      test  (50, 60]
# ...          ...           ...            ...       ...       ...
# 50480   32529.34           0.0            3.0      test  (30, 40]
# 50483  372100.59           6.0            9.0      test  (60, 70]
# 50485   44837.16           2.0            5.0      test  (50, 60]
# 50486   44994.24           1.0            4.0      test  (60, 70]
# 50487  209278.15           0.0            3.0      test  (60, 70]
#
#        tenure_group
# 0       (5.0, 10.0]
# 2        (0.0, 5.0]
# 3      (15.0, 20.0]
# 7      (25.0, 30.0]
# 9      (10.0, 15.0]
# ...             ...
# 50480  (20.0, 25.0]
# 50483  (20.0, 25.0]
# 50485  (15.0, 20.0]
# 50486  (15.0, 20.0]
# 50487  (15.0, 20.0]
#
# [26961 rows x 12 columns]
# Control DataFrame:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 1        2304905             7.0              94.0      58.0     U        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# 5        3727881             5.0              71.0      30.5     U        2.0
# 6         272934             5.0              66.0      58.5     U        2.0
# 8         285619            30.0             369.0      67.5     M        2.0
# ...          ...             ...               ...       ...   ...        ...
# 50474    6662941             7.0              84.0      36.0     F        2.0
# 50479    2787512            23.0             283.0      48.0     F        3.0
# 50481    9932367            23.0             280.0      57.0     F        2.0
# 50482    4079649            23.0             276.0      62.5     M        3.0
# 50484    6967120            21.0             260.0      68.5     M        3.0
#
#               bal  calls_6_mnth  logons_6_mnth variation age_group  \
# 1       110860.30           6.0            9.0   control  (50, 60]
# 4       103671.75           0.0            3.0   control  (30, 40]
# 5        23915.60           0.0            3.0   control  (30, 40]
# 6        27021.42           2.0            5.0   control  (50, 60]
# 8       299388.72           3.0            6.0   control  (60, 70]
# ...           ...           ...            ...       ...       ...
# 50474    83101.84           4.0            7.0   control  (30, 40]
# 50479   123618.60           1.0            4.0   control  (40, 50]
# 50481    94466.55           6.0            9.0   control  (50, 60]
# 50482    57575.28           4.0            7.0   control  (60, 70]
# 50484  4279873.38           6.0            9.0   control  (60, 70]
#
#        tenure_group
# 1       (5.0, 10.0]
# 4      (10.0, 15.0]
# 5        (0.0, 5.0]
# 6        (0.0, 5.0]
# 8      (25.0, 30.0]
# ...             ...
# 50474   (5.0, 10.0]
# 50479  (20.0, 25.0]
# 50481  (20.0, 25.0]
# 50482  (20.0, 25.0]
# 50484  (20.0, 25.0]
#
# [23527 rows x 12 columns]

# %% [markdown]
# There are 26961 clients in the test group and 23527 clients in the control group

# %%
#save test and control file
#test_group_df.to_csv('test_group_df.csv', index=False)

# %%
#control_group_df.to_csv('control_group_df.csv', index=False)
